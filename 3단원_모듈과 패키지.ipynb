# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px"> 프로그래밍: PYTHON</div>
#     <div style="font-weight: bold; font-size: 20px">(3) 모듈과 패키지</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 모듈 만들기 <br>
#     &#x2022; 여러 가지 모듈 활용하기<br>
# </div>

# %% [markdown]
# <div style="font-weight: bold; font-size: 20px">
#     학습목표
# </div>
#
# <div style="padding: 15px; border: 6px solid transparent; border-color: transparent; color: #957F96; margin-bottom: 20px;   border-color: #E0D3E4; font-weight: bold;">
#
# &#x2022; 모듈이 무엇인지 설명할 수 있다. <br>
# &#x2022; 모듈을 정의하거나 임포트하여 사용할 수 있다.
# <br>
# &#x2022; 패키지에 대해 설명하고 활용할 수 있다.
# <br>
#
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 모듈이란?</h2>
#
# </div>

# %%
# 모듈 파일 생성 코드 (3단원 실습 진행 전에 반드시 실행해주세요.)
with open("hello2.py", "w") as f:
    f.write("print(\"hello2 모듈입니다.\")\nprint(\"Hello World?\")")

with open("greeting2.py", "w") as f:
    f.write("print(\"greeting2 모듈입니다.\")\nprint(\"Greeting!\")")

with open("hello_func.py", "w") as f:
    f.write("def hello():\n\tprint(\"hello_func 모듈입니다.\")\n\tprint(\"Hello World?\")")

with open("greeting_func.py", "w") as f:
    f.write("def greeting():\n\tprint(\"greeting_func 모듈입니다.\")\n\tprint(\"__name__ : \", __name__)")

with open("gugudan.py", "w") as f:
    f.write("def gugudan(n):\n\tprint( n, \"단을 출력합니다.\") \n\tfor i in range(1,10):\n\t\tprint( n, \" x \", i, \" = \", n * i ) \n\ngugudan(3)")

# %% [markdown]
# ### **1) 모듈의 개념 및 필요성**

# %% [markdown]
# 지금까지는 모든 코드를 파이썬 파일 하나에 저장했는데, 이렇게 하면 유지 보수가 힘들어진다. 이때 등장
# 하는 것이 모듈이다. 모듈이란 용도에 따라 적절히 나누어 정리한 후 필요한 함수나 클래스만 뽑아 쓸 수 있
# 도록 만든 것이다. 파이썬의 모듈이 무엇인지, 왜 필요한지에 대해 알아보자

# %% [markdown]
# ![image.png](attachment:dcaf44d6-9a79-4f1b-96fe-bea119a40301.png)
# ![image.png](attachment:a55c619c-2593-442e-9b26-f25e9c535766.png)

# %% [markdown]
# ![image.png](attachment:74f89cf3-f5a6-450d-9048-f23e8eccb029.png)
# ![image.png](attachment:a3b904ef-f539-4905-b729-91231d9e6cda.png)
# ![image.png](attachment:7b89f3f6-aea2-43d8-a405-427f416994f0.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #31708f; border-color: #bce8f1;">
#     <div style="font-weight: bold; font-size: 20px">📖 좀 더 알아보기</div>
#     <div style="font-weight: bold; font-size: 15px">
#         &ensp; 모듈, 패키지, 프레임워크의 구조</div>
#
# <br>
#
#   ![image.png](attachment:15180576-70ac-4a97-8340-6c9a18adc5d2.png)
#
# </div>

# %% [markdown]
# ### **2) 모듈의 유형**

# %% [markdown]
# 파이썬 모듈은 안에 들어 있는 코드에 따라 크게 세 종류로 나눌 수 있다. 각 모듈 유형에 대해 살펴보자.

# %% [markdown]
# ![image.png](attachment:d6315b68-daa4-413c-a7b0-3445a66fe959.png)
# ![image.png](attachment:5748c18d-dfc3-4d39-900c-2b4d04f8bc70.png)

# %%
# hello2.py
print("hello2 모듈입니다.")
print("Hello World?")

# %%
# greeting2.py
print("greeting2 모듈입니다.")
print("Greeting!")

# %%
# py 파일 생성 코드 (import 코드 실행 전에 반드시 실행해주세요)
with open("hello2.py", "w") as f:
    f.write("print(\"hello2 모듈입니다.\")\nprint(\"Hello World?\")")

with open("greeting2.py", "w") as f:
    f.write("print(\"greeting2 모듈입니다.\")\nprint(\"Greeting!\")")

# %% [markdown]
# ![image.png](attachment:a67df40e-9c3b-448e-871e-30e0462dcf1e.png)
# ![image.png](attachment:b13fcf0d-b718-4816-9373-701d1797bf7f.png)

# %%
import hello2 # hello2 모듈 임포트하기
import greeting2 # hreeting 모듈 임포트하기

# %% [markdown]
# ![image.png](attachment:a89d2a26-092d-4aa4-b727-69037c0a017f.png)

# %% [markdown]
# ![image.png](attachment:b0675253-7e7e-4deb-bc00-bdb1d71423d8.png)
# ![image.png](attachment:0028ae81-3a2f-47c9-9777-de146ba043ff.png)

# %%
# hello_func.py 
def hello():
    print("hello_func 모듈입니다.")
    print("Hello World?")

# %%
# greeting_func.py
def greeting():
    print("greeting_func 모듈입니다.")
    print("__name__ : ", __name__)

# %%
# py 파일 생성 코드 (import 코드 실행 전에 반드시 실행해주세요)
with open("hello_func.py", "w") as f:
    f.write("def hello():\n\tprint(\"hello_func 모듈입니다.\")\n\tprint(\"Hello World?\")")

with open("greeting_func.py", "w") as f:
    f.write("def greeting():\n\tprint(\"greeting_func 모듈입니다.\")\n\tprint(\"__name__ : \", __name__)")

# %%
import hello_func
import greeting_func

def main():
    print("insa_func 모듈입니다.")
    print("__name__ : ", __name__) # 실행하면 __main__이 출력된다.
    hello_func.hello()
    greeting_func.greeting()
    
main()

# %% [markdown]
# ![image.png](attachment:0fcd8213-cb5c-46ea-a0ea-d1cc8e2fe563.png)

# %% [markdown]
# ![image.png](attachment:70041654-6cb4-4e4d-a5f8-ee7a4b118e92.png)
# ![image.png](attachment:e9279a1a-a3ef-4897-989c-e29246c98364.png)

# %%
# gugudan.py
def gugudan(n):
    print( n, "단을 출력합니다.") 
    for i in range(1,10):
        print( n, " x ", i, " = ", n * i ) 
        
gugudan(3)

# %%
# py 파일 생성 코드 (import 코드 실행 전에 반드시 실행해주세요)
with open("gugudan.py", "w") as f:
    f.write("def gugudan(n):\n\tprint( n, \"단을 출력합니다.\") \n\tfor i in range(1,10):\n\t\tprint( n, \" x \", i, \" = \", n * i ) \n\ngugudan(3)")

# %%
import gugudan
for i in range(2,10):
    print("=" * 20)
    gugudan.gugudan(i)

# %% [markdown]
# ![image.png](attachment:058bab12-ac81-4e1e-888c-573373fe35ea.png)
# ![image.png](attachment:4db73d57-569a-4c96-93e9-6d20c65ab29f.png)

# %%
# gugudan2.py
def gugudan(n):
    print( n, "단을 출력합니다.") 
    for i in range(1,10):
        print( n, " x ", i, " = ", n * i ) 
        
if __name__ == "__main__":
    gugudan(3)

# %% [markdown]
# ![image.png](attachment:290e3055-cde4-4349-98f4-6f8142082c0f.png)

# %%
with open("gugudan2.py", "w") as f:
    f.write("def gugudan(n):\n\tprint( n, \"단을 출력합니다.\") \n\tfor i in range(1,10):\n\t\tprint( n, \" x \", i, \" = \", n * i )" )
    f.write("\n\nif __name__ == \"__main__\":\n\tgugudan(3)")

# %%
import gugudan2

def main():
    for i in range(9,10):
        print("=" * 20)
        gugudan2.gugudan(i)
        
if __name__ == "__main__":
    main()

# %% [markdown]
# ![image.png](attachment:619f2fd1-7e69-47c1-8186-f1e4372032a3.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 모듈 만들기</h2>
#
# </div>

# %% [markdown]
# ### **1) 모듈 정의하기**

# %% [markdown]
# 모듈을 만드는 방법은 무척 간단하다. 파이썬 코드(실행문, 함수, 클래스 등)를 파일로 저장하면 모듈이 된다.
# 다양한 유형의 파이썬 모듈을 정의해 보자.

# %% [markdown]
# ![image.png](attachment:d15ec463-7f5e-4a52-b7b9-c7f889dbda43.png)
# ![image.png](attachment:42c80ea4-cbb4-426a-bae1-7ad7098b107a.png)

# %% [markdown]
# ![image.png](attachment:b7ba7951-ab8d-4758-b099-a15634848241.png)

# %% [markdown]
# ![image.png](attachment:e465d37d-c959-4c24-b3dc-d00e62387f37.png)
# ![image.png](attachment:7614d975-76fd-4ff8-8863-af164c1c112c.png)

# %%
# 이 코드로 area1.py 파일을 생성해보세요.
width = 3
height = 5
print("가로 ", width, " 세로 ", height, "인 삼각형의 넓이 : ", 3 * 5 * 1/2)
print("가로 ", width, " 세로 ", height, "인 사각형의 넓이 : ", 3 * 5)

# %% [markdown]
# ![image.png](attachment:f168a976-e47b-41cd-8eaf-2079120f774d.png)

# %% [markdown]
# ![image.png](attachment:217b15be-4739-4672-b30b-118c7c844e8a.png)
# 앞의 코드를 함수로 만들어 정의하면 다음과 같다.

# %%
# 이 코드로 area2.py 파일을 생성해보세요.
def tri_area(width, height):
    return width * height * 1/2
    
def box_area(width, height):
    return width * height
    
def print_area(width, height):
    print("가로", width," 세로", height,"인 삼각형의 넓이 :", tri_area(width, height) )
    print("가로", width," 세로", height,"인 사각형의 넓이 :", box_area(width, height) )

if __name__ =="__main__":
    print_area(3, 5)
    print_area(6, 10)

# %% [markdown]
# ![image.png](attachment:e6ca29d4-0a7a-4139-b957-d6285d052d39.png)

# %%
import area2

area2.print_area(10, 20)
area2.print_area(20, 30)

for i in range(11, 15):
    area2.print_area(i,20)

print("가로 30 세로 10인 사각형의 넓이는 ", area2.box_area(30, 10))
print(area2.__name__)

# %% [markdown]
# ![image.png](attachment:1b4b3b80-aad9-48f4-8d15-dd7aa9bf6973.png)

# %% [markdown]
# ![image.png](attachment:618521aa-ef2b-4e3f-a0bc-f1f4aa235133.png)
# ![image.png](attachment:5f6a6436-4bd1-4e79-ac22-7054f8a7dc34.png)

# %%
# 이 코드로 area3.py 파일을 생성해보세요
import sys

def tri_area(width, height):
    return width * height * 1/2
    
def box_area(width, height):
    return width * height
    
def print_area(width, height):
    print("가로", width, " 세로", height, "인 삼각형의 넓이 :", tri_area(width, height))
    print("가로", width, " 세로", height, "인 사각형의 넓이 :", box_area(width, height))

if __name__ == "__main__":
    if len(sys.argv) == 3:
        print_area(int(sys.argv[1]), int(sys.argv[2]))
    else:
        print("사용법 : python area3 가로 세로")

# %% [markdown]
# ### **2) 모듈 사용하기**

# %% [markdown]
# ![image.png](attachment:a4f376f6-6ecb-4787-81b0-abb06bc3d248.png)다

# %% [markdown]
# import 문을 사용하여 모듈을 불러온 뒤 해당 모듈 이름 뒤에 ‘.’를 붙이고
# 그 모듈 안에 있는 함수 또는 클래스를 참조해서 사용할 수 있다.
# 직접 만든 모듈과 이 모듈을 활용하는 예제를 보자.

# %%
# repeater.py
def repeat(s, n=3):
    print(((s + ",") * (n-1)) + s)
def once(s):
    print(s)

# %%
# repeater.py 파일 생성 코드 (다음 실습 코드 실행 전에 반드시 실행시켜 주세요)
with open("repeater.py", "w") as f:
    f.write("def repeat(s, n=3):\n\tprint(((s + \",\") * (n-1)) + s)")
    f.write("\ndef once(s):\n\tprint(s)")

# %%
import repeater

s = input("반복할 문자를 입력하세요 : ")
n = input("반복 횟수를 입력하세요 : ")

repeater.repeat(s, int(n))
repeater.repeat(s)
repeater.once(s)

# %% [markdown]
# ![image.png](attachment:ff7ca425-d96a-4c2b-94ca-963422054bd0.png)
# ![image.png](attachment:dd1d4f53-f38b-441b-b256-7862ca1ab1c2.png)

# %%
from repeater import repeat, once

s = input("반복할 문자를 입력하세요 : ")
n = input("반복 횟수를 입력하세요 : ")

repeat(s, int(n))
repeat(s)
once(s)

# %% [markdown]
# ![image.png](attachment:67d7ddf9-4d27-4fb6-9c46-962b70450a2f.png)
# ![image.png](attachment:01dc6a5e-1943-49f8-973a-bfe7bc37a528.png)

# %%
from repeater import *

s = input("반복할 문자를 입력하세요 : ")
n = input("반복 횟수를 입력하세요 : ")

repeat(s, int(n))
repeat(s)
once(s)

# %% [markdown]
# ![image.png](attachment:d7db9e71-fa01-49eb-b362-157602b5c6e2.png)
# ![image.png](attachment:143963df-9cc4-48fc-ab07-e0a0e7d113df.png)

# %%
import repeater as r

s = input("반복할 문자를 입력하세요 : ")
n = input("반복 횟수를 입력하세요 : ")

r.repeat(s, int(n))
r.repeat(s)
r.once(s)

# %% [markdown]
# ![image.png](attachment:9dfaac55-73f8-4bf5-87e1-8faf6fe29211.png)
# ![image.png](attachment:0f6ae828-783d-438a-a66f-a746179b45d5.png)

# %%
import sys
print(sys.path)

# %% [markdown]
# ![image.png](attachment:ed3fbefb-178a-4ac3-94df-87b554f8fad2.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 패키지란?</h2>
#
# </div>

# %% [markdown]
# ### **1) 패키지 정의하기**

# %% [markdown]
# 패키지란 모듈들을 구조화하여 관리하기 위해 모듈을 나눠 놓은 것이다. 패키지가 무엇이며 어떻게 만들 수
# 있는지 살펴보자.

# %% [markdown]
# ![image.png](attachment:352db9dd-f012-40fa-93dd-56c70b62e73f.png)
# ![image.png](attachment:8151f976-d3b4-4926-8265-b030ad58792a.png)
# ![image.png](attachment:6fd52ff6-e959-4ca2-9d6d-e9b4b35067ff.png)
# ![image.png](attachment:662fee8a-5013-4209-8e2b-52526d9850f5.png)
# ![image.png](attachment:08b2de5e-b1e9-4c9c-9ba1-2b06417382d5.png)

# %%
# 제시한 폴더 구조를 만들고, milk.py 파일에 아래의 코드를 저장해주세요.
def drink():
    print("꿀꺽꿀꺽~ 진하고 신선한 우유의 향연이~!")

# %%
from foods.drinks import milk

milk.drink()

# %% [markdown]
# ![image.png](attachment:17cf141f-1308-4547-8461-4952bc892cd3.png)

# %% [markdown]
# ![image.png](attachment:e37b4e55-3e66-4f6f-b236-e83850ea18c3.png)
# ![image.png](attachment:7f9ffb07-832e-4223-9443-4cd1e404352f.png)

# %%
# fruits 패키지 안의 __init__.py 파일에 아래의 코드를 저장해주세요.
__all__ = ['orange', 'watermelon', 'apple']

# %% [markdown]
# ![image.png](attachment:6b9ae404-5f43-479b-8f6e-563b12d3ca06.png)

# %%
from foods.fruits import *

# %% [markdown]
# ![image.png](attachment:29a0f667-00a1-43bf-a5d1-f53d4e17633c.png)

# %%
# __init__.py 파일에 작성
__all__ = ['orange']

# orange.py 파일에 작성
def eat():
    print("오랭오랭~ 오렌쥐!")

# apple.py 파일에 작성
def eat():
    print("아삭아삭~ one more thing, apple!")

# %%
from foods.fruits import *
orange.eat() # 문제없이 호출된다.

# %% [markdown]
# ![image.png](attachment:d2a0061f-ef8d-4b1a-80a1-d5c1bc34db0d.png)

# %%
from foods.fruits import *

orange.eat() # 문제없이 호출된다.
apple.eat() # 에러! apple 모듈을 못 찾는다!

# %% [markdown]
# ![image.png](attachment:35182f88-7fcb-443d-baab-fe357023bd72.png)

# %% [markdown]
# ### **2) 패키지 사용하기**

# %% [markdown]
# 패키지를 임포트하여 사용하는 방식이 여러 가지 있는데, 각 경우에 따라 참조해서 호출하는 방식이 달라져
# 주의가 필요하다. 패키지를 임포트하여 사용하는 다양한 방법을 살펴보자.

# %% [markdown]
# ![image.png](attachment:bacb4484-226a-4c0e-975c-d639dfad5b2d.png)
# ![image.png](attachment:8327106c-08be-43f5-a18a-b00f0b8fe886.png)

# %%
from foods.drinks import milk
milk.drink()

# %% [markdown]
# ![image.png](attachment:45ee2f97-1119-4d41-8bc2-91a660202692.png)
# ![image.png](attachment:24bcb704-0cfc-43b3-b723-862087ca54a9.png)

# %%
from foods.drinks import milk as m
m.drink()

# %% [markdown]
# ![image.png](attachment:0af4f4b0-c8f6-401c-a9ee-a130daa1612f.png)
# ![image.png](attachment:8c0e22b0-05be-4637-a465-06a653ac7191.png)

# %%
from foods.drinks.milk import drink
drink()

# %% [markdown]
# ![image.png](attachment:cf138911-bad8-4d0f-a429-c8ce572d1b26.png)
# ![image.png](attachment:767fa52a-288f-42ad-b494-4387faed8c99.png)

# %%
from foods.drinks.milk import *
drink()

# %% [markdown]
# ![image.png](attachment:e3835533-77d1-49a8-94c9-730023c22213.png)
# ![image.png](attachment:95311c95-be17-41e8-968c-64f76de3e358.png)

# %%
import foods.drinks.milk
foods.drinks.milk.drink()

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>4. 여러 가지 모듈 활용하기</h2>
#
# </div>

# %% [markdown]
# ### **1) 표준 라이브러리 활용하기**

# %% [markdown]
# 파이썬에는 바로 사용할 수 있는 다양한 종류의 신뢰도 높은 모듈들이 제공된다. 이러한 모듈을 미리 파악
# 해 필요할 때 찾아서 쓸 수 있어야 좋은 프로그램을 빠르게 작성할 수 있다. 표준 라이브러리에서 제공하는
# 모듈들을 살펴보자.

# %% [markdown]
# ![image.png](attachment:33f1e735-4911-48eb-a77e-651a217abe12.png)
# ![image.png](attachment:72cffcbc-63bd-4a00-a911-9e90d228e6ac.png)

# %% [markdown]
# ![image.png](attachment:26d88d59-3432-4f1d-b247-e2832fb44002.png)
# ![image.png](attachment:763a4e24-ad44-4b8f-a0b4-47183c1436a4.png)
#
# [API 문서 링크](https://docs.python.org/ko/3/library/os.html#module-os)

# %%
import os
print("현재 작업 디렉터리는", os.getcwd(), "입니다.")
os.system('dir') # 운영체제가 파일, 디렉터리 목록을 보여주는
                 # dir 명령을 실행하도록 요청합니다.

# %% [markdown]
# ![image.png](attachment:85025cfb-9a93-4cc2-a56f-db4f25be0e8e.png)
# ![image.png](attachment:d01cadde-2190-49b4-8659-6cf72b10016b.png)
#
# [API 문서 링크](https://docs.python.org/ko/3/library/sys.html#module-sys)

# %%
import sys
print('실행 파일명:', sys.argv[0])
for i in range(1,len(sys.argv)):
    print('옵션', i, ':', sys.argv[i])
sys.exit()

for i in range(1,100):
    print('여기는 실행되지 않습니다.')

# %% [markdown]
# ![image.png](attachment:8f9be89b-eee4-470b-9d68-9212e190bfd3.png)
# ![image.png](attachment:64faedbe-b3a8-4e2f-99e8-8d362d379174.png)

# %%
import math

print('파이 상수')
print('math.pi :', math.pi)
print()
print('e 상수')
print('math.e :', math.e)
print()
print('올림 - 3.5의 올림')
print('math.ceil(3.5) :', math.ceil(3.5))
print()
print('내림 - 3.5의 내림')
print('math.floor(3.5) :', math.floor(3.5))
print()
print('계승 구하기 - 5!(5계승)')
print('math.factorial(5) :', math.factorial(5))
print()
print('최대공약수 구하기 - 28과 70의 최대공약수')
print('math.gcd(28,70) :', math.gcd(28,70))
print()
print('거듭제곱 구하기 - 2의 10승 (2^10)')
print('math.pow(2,10) :', math.pow(2,10))
print()
print('삼각함수 - sin(1/2 π)')
print('math.sin(math.pi/2) :', math.sin(math.pi/2))
print()
print('삼각함수 - cos(π)')
print('math.cos(math.pi) :', math.cos(math.pi))
print()
print('삼각함수 - tan(0)')
print('math.tan(0) :', math.tan(0))

# %% [markdown]
# ![image.png](attachment:bae93e28-4aaa-4cfa-b3dd-326163ec56bd.png)
# ![image.png](attachment:5668db53-70a5-4017-8987-27347ab349e8.png)
#
# [API 문서 링크](https://docs.python.org/ko/3/library/random.html#module-random)

# %%
import random

print('0 이상 1 미만 실수 값')
print('random.random() :', random.random())
print()
print('시작값 2.5 이상 끝값 10.0 미만 실수 값')
print('random.uniform(2.5, 10.0) :', random.uniform(2.5, 10.0))
print()
print('0 이상 끝값 10 미만 정수 값')
print('random.randrange(10) :', random.randrange(10))
print()
print('1 이상 끝값 7 미만, 증가 값이 2인 정수 값')
print('random.randrange(1,7,2) :', random.randrange(1,7,2))
print()
print('리스트에서 1개 값 꺼내오기')
season = ['봄', '여름', '가을', '겨울']
print('season = ', season)
print('random.choice(season) :', random.choice(season))
print()
list_a=['가', '나', '다', '라', '마']
print('리스트 순서를 섞기')
print('섞기 전 list_a = ', list_a)
random.shuffle(list_a)
print('random.shuffle(list_a)')
print('섞은 후 list_a = ', list_a)
print()
print('리스트에서 몇 개의 값을 중복하지 않고 3개 뽑기')
sample=['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번', '9번']
print('샘플 대상 = ', sample)
print('random.sample(sample,3) :', random.sample(sample, 3))

# %% [markdown]
# ![image.png](attachment:549fdf27-a838-4322-aa96-3a82db845323.png)
# ![image.png](attachment:e127b3fd-b127-4bd4-b38c-0418a54fcd54.png)
#
# [API 문서 링크](https://docs.python.org/ko/3/library/datetime.html#module-datetime)

# %%
from datetime import datetime

print('현재 날짜 시각 객체 얻기')
today = datetime.now()
print('today = datetime.now() :', today)
print('연, 월, 일 :', today.year, today.month, today.day)
print('시, 분, 초 :', today.hour, today.minute, today.second)
print('요일 : ', today.weekday())
print('특정 날짜 시각 객체 만들기')
day = datetime(2018, 1, 1, 0, 0, 0)
print('day = datetime(2018, 1, 1, 0, 0, 0) :', day)
print('2018년부터 지나온 시간 구하기')
print('today - day:', today - day )

# %% [markdown]
# ### **2) 써드파티 패키지 활용하기**

# %% [markdown]
# ![image.png](attachment:5dc70657-7fea-475c-a17b-500cbe186028.png)
# ![image.png](attachment:fd386307-2b1a-456d-9897-624ec7217874.png)

# %% [markdown]
# ![image.png](attachment:d0f35a80-7387-46a9-8909-6b2199e7cc23.png)
# ![image.png](attachment:de1a5484-6a4a-42b9-8c8b-03e98ff60591.png)
# ![image.png](attachment:1e0c733c-c851-421e-9a12-4424f6c4b371.png)

# %%
 # 명령어 앞에 느낌표(!)를 붙이면 주피터 노트북에서 명령 프롬프트를 사용할 수 있습니다. 
# !pip install peewee

# %% [markdown]
# ![image.png](attachment:a53061c9-9175-441a-9791-d590416de352.png)
# ![image.png](attachment:0615b725-b8b4-46d8-a76d-6c628551e6db.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #8a6d3b;  border-color: #faebcc;">
#     <div style="font-weight: bold; font-size: 20px">💯 실습하기</div>
#     <br>
#
# 다음과 같은 calculator 모듈과 이를 사용하는 calmain 모듈이 있고, 실행 결과는 다음과 같다고 하자. calmain 모듈을 정의하고 하단의 셀들을 실행시키시오.
#
# </div>

# %%
from calculator import add
add(1, 2)

# %%
import calculator
calculator.sub(2, 1)

# %%
from calculator import mul
mul(3, 4)

# %%
from calculator import *
div(4, 2)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3baea0; border-color: #93e4c1;">
#     <div style="font-weight: bold; font-size: 20px">💯 단원 평가</div>
#     <br>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="AAK-pRHGI5U" href='#jce-judge/open/AAK-pRHGI5U' target='_self'><span>모듈 불러오기  </span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="coG96VHfdZY" href='#jce-judge/open/coG96VHfdZY' target='_self'><span>모듈 만들기</span></a>
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="TYd0cu5Z7Rk" href='#jce-judge/open/TYd0cu5Z7Rk' target='_self'><span>로또 번호</span></a>
#
#
# </div>
