# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; background-color: #dff0d8; border-color: #d6e9c6; font-weight: bold;">
#     <br><br>
#     <div style="font-weight: bold; font-size: 40px"> 프로그래밍: PYTHON</div>
#     <div style="font-weight: bold; font-size: 20px">(7) 프로젝트</div>
#     <hr style="width:80%;text-align:left;margin-left:0;border:0.5px solid green">
#     <br>
#     &#x2022; 프로그램 기획 <br>
#     &#x2022; 프로그램 설계 <br>
#     &#x2022; 프로그램 구현 <br>
# </div>

# %% [markdown]
# <div style="font-weight: bold; font-size: 20px">
#     학습목표
# </div>
#
# <div style="padding: 15px; border: 6px solid transparent; border-color: transparent; color: #957F96; margin-bottom: 20px;   border-color: #E0D3E4; font-weight: bold;">
#
# &#x2022; 프로그램 기획서를 작성할 수 있다. <br>
# &#x2022; 프로그램에 필요한 클래스와 그 기능을 정리할 수 있다.<br>
# &#x2022; 기초적인 GUI 프로그램을 작성할 수 있다.<br>
# &#x2022; tkinter 모듈에서 제공하는 함수를 활용할 수 있다.<br>
#
# </div>

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>1. 프로그램 기획</h2>
#
# </div>

# %% [markdown]
# ### **1) 프로그램 아이디어 기획**

# %% [markdown]
# 프로그램을 작성할 때 코드 입력부터 무작정 시작하는 것보다 먼저 프로그램 작성과 관련된 기획서를 써
# 보는 것이 좋다. 기획서 작성 과정을 통해 어떤 프로그램을 만들 것인지 주제를 선정하고 구현을 위한 기
# 반 기술과 현실적인 진행 일정도 계획할 수 있기 때문이다. 프로그램 기획의 단계를 순서대로 알아보자.

# %% [markdown]
# ![image.png](attachment:9b3bc585-9ca2-48fc-b22f-fe33e639457d.png)
# ![image.png](attachment:4b02063a-ea7b-4610-9484-91b94d84373c.png)

# %% [markdown]
# ![image.png](attachment:1c7d53c8-8222-4996-9bac-4be74a2b0c75.png)
# ![image.png](attachment:43b2b89a-b6cf-40b5-823d-0d1ecaa1b86f.png)

# %% [markdown]
# ![image.png](attachment:2b9ba431-24af-4336-826f-336db09a6bf0.png)
# ![image.png](attachment:629b6254-8263-47a5-a766-4cd27a5b219b.png)

# %% [markdown]
# ![image.png](attachment:f6006f4c-c86a-4180-a49f-7b76db312581.png)
# ![image.png](attachment:7f3b2ea9-72ed-44af-9c08-6b257b5aef1e.png)

# %% [markdown]
# ### **2) 틱택토 게임 프로그램 기획서 작성**

# %% [markdown]
# 이제 예시를 통해 프로그램 기획서를 실제로 작성해 보자. 주제는 간단한 게임 개발로 한다.

# %% [markdown]
# ![image.png](attachment:02e4c440-1471-4321-a5f0-cffdba7229a2.png)
# ![image.png](attachment:5ea3b1ce-f2c9-4a85-802d-7f4929ba222c.png)
# ![image.png](attachment:43c880fe-fcfd-4424-ae29-b8b5e4f61e54.png)

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>2. 프로그램 설계</h2>
#
# </div>

# %% [markdown]
# ### **1) 클래스 설계**

# %% [markdown]
# 성공적으로 객체 지향 프로그램을 작성하려면 프로그램에 어떤 클래스들이 필요한지 알아야 하며, 각 클
# 래스의 역할과 협력 관계를 설정할 수 있어야 한다. 클래스를 잘 설계하려면 어떤 사안들을 고려해야 하는
# 지 살펴보자.

# %% [markdown]
# ![image.png](attachment:b4857210-a3f7-4ea0-9c25-550e5d4356e6.png)
# ![image.png](attachment:691b3d58-8072-4d74-b391-be0498b134a3.png)

# %% [markdown]
# ![image.png](attachment:c68937eb-6417-4d60-9e69-d7ce61e50910.png)
# ![image.png](attachment:2d4dd1d8-19e7-476f-bc34-a4c02e0e1710.png)

# %% [markdown]
# ![image.png](attachment:80da703c-524a-4e8f-8d28-9f6c18dae297.png)
# ![image.png](attachment:f1eba4f2-623e-476d-a69b-72835bfdc9a0.png)

# %% [markdown]
# ![image.png](attachment:75fb55a5-b03b-4714-8897-622af7c62011.png)
# ![image.png](attachment:2f74e529-c0b9-419e-9ea3-8eb09179a827.png)

# %% [markdown]
# ### **2) 틱택토 클래스 설계**

# %% [markdown]
# 틱택토 게임에 필요한 클래스를 설계하기 위해 해당 클래스에 필요한 멤버 변수와 기능(메소드)을 정리해
# 보자.

# %% [markdown]
# ![image.png](attachment:e594866a-cc5f-4919-bf2e-ab7723c918bf.png)
# 다음은 틱택토 클래스에 필요한 멤버 변수와 그 역할을 정리한 표이다.
# ![image.png](attachment:deeb3027-1f95-4124-b66c-2ccacbb53514.png)

# %% [markdown]
# ![image.png](attachment:cf9f07aa-95cd-4f00-b4a6-d1403ca245f7.png)
# 다음은 틱택토 클래스에 필요한 메소드와 그 역할을 정리한 표이다.
# ![image.png](attachment:32cd6db3-3f60-4628-80a1-528da17879e4.png)
#
# 코드부터 짜는 것보다 이런 식으로 대략적인 필요 멤버 변수와 메소드의 역할을 정리해 보는 과정을 거치면 클래스의 역할을 더 명확하게 알 수 있고 기능 테스트도 쉽게 진행할 수 있다.

# %% [markdown]
# <div style="padding: 15px; border: 5px solid transparent; border-color: transparent; margin-bottom: 20px; border-radius: 4px; color: #3c763d; border-color: #d6e9c6; font-weight: bold;">
# <h2 style='font-weight: bold'>3. 프로그램 구현</h2>
#
# </div>

# %% [markdown]
# ### **1) 콘솔 기반 프로그램 구현**

# %% [markdown]
# ![image.png](attachment:48ea1fd4-92a3-41a5-9b55-9ece22488fb3.png)
# ![image.png](attachment:d1153335-2d78-4161-bdb3-372d6724e544.png)

# %%
from PIL import Image
import matplotlib.pyplot as plt

class TicTacToe:
    def add(self, x, y, c):
        if self.game_end:
            return
        if self.current_turn != c:
            return
        if self.board[(x * 3) + y] != "n":
            return

        self.board[(x * 3) + y] = c
        self.current_turn = "O" if self.current_turn == "X" else "X"
    
        self.winner = self.check_winner()
        if self.winner == "O" or self.winner == "X":
            print("게임 종료", self.winner + "가 이겼습니다.")
            self.game_end = True
        elif self.winner == "d":
            print("게임 종료", "무승부입니다.")
            self.game_end = True

# %%
class TicTacToe:
    # (… 생성자 __init__ 메소드 내용 생략 …)
    # (… add 메소드 내용 생략 …)
    def check_winner(self):
        for check in ["O", "X"]:
            for i in range(0, 3):
                if self.board[i * 3 + 0] == check and  self.board[i * 3 + 1] == check and  self.board[i * 3 + 2] == check:
                    return check
                if self.board[0 * 3 + i] == check and  self.board[1 * 3 + i] == check and  self.board[2 * 3 + i] == check:
                    return check
                if (self.board[0] == check and self.board[4] \
                    == check and self.board[8] == check) or  (self.board[2] == check and self.board[4] \
                    == check and self.board[6] == check):
                    return check
                    
        has_empty_cell = False
        for idx, val in enumerate(self.board):
             if val == "n":
                 has_empty_cell = True
                 break
        return "." if has_empty_cell else "d"

# %% [markdown]
# ![image.png](attachment:95697742-596e-49c0-a425-12f9b53e78a5.png)
# ![image.png](attachment:77a7eaf2-49b4-411c-945d-4eaae2472012.png)

# %%
class TicTacToe:
    # (… 생성자 __init__ 메소드 내용 생략 …)
    # (… add 메소드 내용 생략 …)
    # (… check_winner 메소드 내용 생략 …)
    def get_winner(self):
        return self.winner
        
    def get_current_turn(self):
        return self.current_turn
        
    def get(self, x, y):
        return self.board[(x * 3) + y]

# %% [markdown]
# ![image.png](attachment:4ed632d3-3000-4fda-a2f9-1ece88c57775.png)

# %% [markdown]
# ### **2) 이미지 출력 프로그램 구현**

# %% [markdown]
# ![image.png](attachment:8e6d9994-80b6-4936-8e2d-d83831fde4f6.png)

# %%
# 전체 클래스 정의
class TicTacToe:
    def __init__(self, start_turn):
        self.winner = "."
        self.board = ["n", "n", "n", "n", "n", "n", "n", "n", "n"]
        self.game_end = False
        self.current_turn = start_turn

    # (… 이하 틱택토 클래스 메소드는 소스가 같으므로 생략 …)

# %% [markdown]
# ![image.png](attachment:9c536de7-a177-407b-b0f3-2f37b36a9f29.png)

# %%
# 전체 클래스 정의
class TicTacToe:
    
    # (… 틱택토 클래스 메소드는 소스가 같으므로 생략함 …)
    
    def draw_board(self):
        image_paths = [f"./player_{self.board[0]}.PNG", f"./player_{self.board[1]}.PNG", f"./player_{self.board[2]}.PNG",
                       f"./player_{self.board[3]}.PNG", f"./player_{self.board[4]}.PNG", f"./player_{self.board[5]}.PNG",
                       f"./player_{self.board[6]}.PNG", f"./player_{self.board[7]}.PNG", f"./player_{self.board[8]}.PNG"]
        fig, axes = plt.subplots(3, 3, figsize=(3, 3))
        # 이미지 로드
        images = [Image.open(path) for path in image_paths]

        # 각 이미지를 그리드에 넣기
        for i in range(3):
            for j in range(3):
                index = i * 3 + j
                if index < len(images):
                    axes[i, j].imshow(images[index])
                    axes[i, j].axis("off")
                    
        plt.show()
        
    def clear_board(self):
        self.board = ["n", "n", "n", "n", "n", "n", "n", "n", "n"]

# %% [markdown]
# ![image.png](attachment:738f5761-e5a1-4a31-b6db-25979c252eee.png)

# %%
ttt = TicTacToe("O")
while ttt.winner=='.':
    x, y = map(int, input().split())
    ttt.add(x, y, ttt.current_turn)
    ttt.draw_board()
    plt.show()

# %% [markdown]
# ![image.png](attachment:9de7ce1d-de1c-44f2-9ac2-f1aee0b1a439.png)

# %%
class GameManager:
    def __init__(self):
        self.ttt = TicTacToe('O')

    def start(self):
        self.ttt.clear_board()
        self.turn = self.ttt.get_current_turn()
        while self.ttt.winner=='.':
            x, y = map(int, input().split())
            self.ttt.add(x, y, self.turn)
            self.ttt.draw_board()
            plt.show()

gm = GameManager()
gm.start()

# %% [markdown]
# 다음은 완성된 틱택토 게임의 최종 소스 코드이다.

# %%
from PIL import Image
import matplotlib.pyplot as plt


# 전체 클래스 정의
class TicTacToe:
    def __init__(self, start_turn):
        self.winner = "."
        self.board = ["n", "n", "n", "n", "n", "n", "n", "n", "n"]
        self.game_end = False
        self.current_turn = start_turn

    def add(self, x, y, c):
        if self.game_end:
            return
        if self.current_turn != c:
            return
        if self.board[(x * 3) + y] != "n":
            return

        self.board[(x * 3) + y] = c
        self.current_turn = "O" if self.current_turn == "X" else "X"
    
        self.winner = self.check_winner()
        if self.winner == "O" or self.winner == "X":
            print("게임 종료", self.winner + "가 이겼습니다.")
            self.game_end = True
        elif self.winner == "d":
            print("게임 종료", "무승부입니다.")
            self.game_end = True

    def check_winner(self):
        for check in ["O", "X"]:
            for i in range(0, 3):
                if self.board[i * 3 + 0] == check and  self.board[i * 3 + 1] == check and  self.board[i * 3 + 2] == check:
                    return check
                if self.board[0 * 3 + i] == check and  self.board[1 * 3 + i] == check and  self.board[2 * 3 + i] == check:
                    return check
                if (self.board[0] == check and self.board[4] \
                    == check and self.board[8] == check) or  (self.board[2] == check and self.board[4] \
                    == check and self.board[6] == check):
                    return check
                    
        has_empty_cell = False
        for idx, val in enumerate(self.board):
             if val == "n":
                 has_empty_cell = True
                 break
        return "." if has_empty_cell else "d"

    def get_winner(self):
        return self.winner
        
    def get_current_turn(self):
        return self.current_turn
        
    def get(self, x, y):
        return self.board[(x * 3) + y]

    def show_board(self, i):
        pass

    def draw_board(self):
        image_paths = [f"./player_{self.board[0]}.PNG", f"./player_{self.board[1]}.PNG", f"./player_{self.board[2]}.PNG",
                       f"./player_{self.board[3]}.PNG", f"./player_{self.board[4]}.PNG", f"./player_{self.board[5]}.PNG",
                       f"./player_{self.board[6]}.PNG", f"./player_{self.board[7]}.PNG", f"./player_{self.board[8]}.PNG"]
        fig, axes = plt.subplots(3, 3, figsize=(3, 3))
        # 이미지 로드
        images = [Image.open(path) for path in image_paths]

        # 각 이미지를 그리드에 넣기
        for i in range(3):
            for j in range(3):
                index = i * 3 + j
                if index < len(images):
                    axes[i, j].imshow(images[index])
                    axes[i, j].axis("off")
                    
        plt.show()
        
    def clear_board(self):
        self.board = ["n", "n", "n", "n", "n", "n", "n", "n", "n"]


class GameManager:
    def __init__(self):
        self.ttt = TicTacToe('O')

    def start(self):
        self.ttt.clear_board()
        self.turn = self.ttt.get_current_turn()
        while self.ttt.winner=='.':
            x, y = map(int, input().split())
            self.ttt.add(x, y, self.turn)
            self.ttt.draw_board()
            plt.show()

if __name__=='__main__':
    gm = GameManager()
    gm.start()
